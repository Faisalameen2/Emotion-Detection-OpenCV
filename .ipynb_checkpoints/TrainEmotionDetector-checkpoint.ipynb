# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %%
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(1./255)

# %%
train_generator = train_data_gen.flow_from_directory("Data/train", target_size=(48,48),
                                                    batch_size=64, color_mode = "grayscale", 
                                                    class_mode="categorical")
# Out:
# Found 28709 images belonging to 7 classes.

# %%
#Preprocessing the train images

val_generator = train_data_gen.flow_from_directory("Data/test", target_size=(48,48),
                                                    batch_size=64, color_mode = "grayscale", 
                                                    class_mode="categorical")
# Out:
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()

# %%
emotion_model.add(Conv2D(34, kernel_size=(3,3), activation="relu", input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3,3), activation="relu"))
emotion_model.add(MaxPooling2D(pool_size=(2,2)))
emotion_model.add(Dropout(0.25))


emotion_model.add(Conv2D(128, kernel_size=(3,3), activation="relu"))
emotion_model.add(MaxPooling2D(pool_size=(2,2)))
emotion_model.add(Conv2D(128, kernel_size=(3,3), activation="relu"))
emotion_model.add(MaxPooling2D(pool_size=(2,2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024,activation="relu"))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation="softmax"))

# %%
emotion_model.compile(loss="categorical_crossentropy", 
                     optimizer=Adam(learning_rate=0.0001, decay= 1e-6), metrics=["accuracy"])

# %%
#Train the Neural Network Model

emotion_model_info = emotion_model.fit(train_generator,
                                                  steps_per_epoch = 28709//64,
                                                  epochs =100,
                                                  validation_data = val_generator,
                                                  validation_steps = 7178//64)
# Out:
# Epoch 1/100
# 448/448 [==============================] - 363s 805ms/step - loss: 1.7975 - accuracy: 0.2629 - val_loss: 1.6929 - val_accuracy: 0.3322
# Epoch 2/100
# 448/448 [==============================] - 219s 489ms/step - loss: 1.6200 - accuracy: 0.3726 - val_loss: 1.5403 - val_accuracy: 0.4178
# Epoch 3/100
# 448/448 [==============================] - 218s 486ms/step - loss: 1.5217 - accuracy: 0.4149 - val_loss: 1.4557 - val_accuracy: 0.4407
# Epoch 4/100
# 448/448 [==============================] - 215s 480ms/step - loss: 1.4508 - accuracy: 0.4437 - val_loss: 1.4035 - val_accuracy: 0.4688
# Epoch 5/100
# 448/448 [==============================] - 214s 477ms/step - loss: 1.3931 - accuracy: 0.4666 - val_loss: 1.3380 - val_accuracy: 0.4939
# Epoch 6/100
# 448/448 [==============================] - 211s 471ms/step - loss: 1.3390 - accuracy: 0.4893 - val_loss: 1.3043 - val_accuracy: 0.5067
# Epoch 7/100
# ...

# %%
model_json = emotion_model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)
    
emotion_model.save_weights("emotion_model.h5")
